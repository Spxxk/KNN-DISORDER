# %%
import numpy as np
import pandas as pd

# %%
file_path = 'dataset.xlsx'
df = pd.read_excel(file_path)

# %%
df
# Out:
#      ag+1:629e  feeling.nervous  panic  breathing.rapidly  sweating  \
# 0           23                1      0                  1         0
# 1           14                1      0                  1         0
# 2           25                0      0                  0         0
# 3           29                1      0                  0         0
# 4           32                1      1                  1         1
# ..         ...              ...    ...                ...       ...
# 632         23                1      0                  1         1
# 633         27                1      0                  1         0
# 634         19                0      1                  0         0
# 635         16                1      0                  0         0
# 636         14                1      0                  1         0
#
#      trouble.in.concentration  having.trouble.in.sleeping  \
# 0                           0                           1
# ...

# %%
df.columns
# Out:
# Index(['ag+1:629e', 'feeling.nervous', 'panic', 'breathing.rapidly',
#        'sweating', 'trouble.in.concentration', 'having.trouble.in.sleeping',
#        'having.trouble.with.work', 'hopelessness', 'anger', 'over.react',
#        'change.in.eating', 'suicidal.thought', 'feeling.tired', 'close.friend',
#        'social.media.addiction', 'weight.gain', 'introvert',
#        'popping.up.stressful.memory', 'having.nightmares',
#        'avoids.people.or.activities', 'feeling.negative',
#        'trouble.concentrating', 'blamming.yourself', 'hallucinations',
#        'repetitive.behaviour', 'seasonally', 'increased.energy', 'Disorder'],
#       dtype='object')

# %%
df.iloc[0]['Disorder']
# Out:
# 'MDD'

# %%
# 1-NN
a = ['ag+1:629e', 'panic', 'hopelessness', 'anger', 'hallucinations']

# %%
person_1 = {'ag+1:629e': 15, 'panic': 0, 'hopelessness': 0, 'anger': 1, 'hallucinations': 0}

# %%
def custom_calculation(row):
    # Example calculation: Let's say we calculate a score based on the length of the city name and age
    score = abs(row['ag+1:629e'] - person_1['ag+1:629e']) \
        + abs(row['panic'] - person_1['panic']) \
        + abs(row['hopelessness'] - person_1['hopelessness']) \
        + abs(row['anger'] - person_1['anger']) \
        + abs(row['hallucinations'] - person_1['hallucinations'])
    return score

# %%
df['CalculatedValue'] = df.apply(custom_calculation, axis=1)
df['CalculatedValue']
# Out:
# 0      10
# 1       1
# 2      11
# 3      15
# 4      19
#        ..
# 632     9
# 633    13
# 634     6
# 635     2
# 636     1
# Name: CalculatedValue, Length: 637, dtype: int64

# %%
min_value = df['CalculatedValue'].min()
min_value
# Out:
# 0

# %%
min_value_rows = df[df['CalculatedValue'] == min_value]
min_value_rows
# Out:
#      ag+1:629e  feeling.nervous  panic  breathing.rapidly  sweating  \
# 65          15                1      0                  0         0
# 126         15                1      0                  0         0
# 194         15                1      0                  0         0
# 280         15                1      0                  0         0
# 301         15                1      0                  0         0
# 474         15                1      0                  0         0
# 594         15                1      0                  0         0
#
#      trouble.in.concentration  having.trouble.in.sleeping  \
# 65                          0                           0
# 126                         0                           0
# 194                         0                           0
# 280                         0                           0
# 301                         0                           0
# 474                         0                           0
# ...

# %%
min_value_rows['Disorder']
# Out:
# 65     ASD
# 126    ASD
# 194    ASD
# 280    ASD
# 301    ASD
# 474    ASD
# 594    ASD
# Name: Disorder, dtype: object
